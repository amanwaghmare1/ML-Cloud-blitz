# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\amanw\\OneDrive\\Desktop\\project6\\financial_dataset.csv")

# %%
print(df.shape)
print(df.info())
print(df.describe())
print(df.head())
print(df.columns)
# Out:
# (10000, 16)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Age                           9500 non-null   float64
#  1   Annual_Income                 9500 non-null   float64
#  2   Monthly_Expenses              9500 non-null   float64
#  3   Savings_Rate                  9500 non-null   float64
#  4   Debt_to_Income_Ratio          9505 non-null   float64
#  5   Current_Investments_Value     9500 non-null   float64
#  6   Total_Loan_Amount             9500 non-null   float64
#  7   Avg_Credit_Score              9500 non-null   float64
#  8   Inflation_Rate                9500 non-null   float64
#  9   Interest_Rate                 9500 non-null   float64
#  10  Years_of_Employment           9500 non-null   float64
#  11  Job_Stability_Score           9500 non-null   float64
# ...

# %%
num_cols = df.select_dtypes(include=['float64', 'int64']).columns.tolist()
